# %%
import pandas as pd

# %%
covidData = pd.read_excel("database/dados-preprocessados.xlsx")

# %%
covidData
# Out:
#      CS_SEXO NU_IDADE_N  CS_RACA  SURTO_SG  FEBRE  TOSSE  GARGANTA  DISPNEIA  \
# 0          0    ADULTO3        4         2      1      1         1         1
# 1          1     IDOSO1        4         2      1      1         1         1
# 2          1    ADULTO3        4         2      1      1         2         1
# 3          1    ADULTO3        4         2      1      1         2         1
# 4          1     IDOSO1        4         2      1      1         2         1
# ..       ...        ...      ...       ...    ...    ...       ...       ...
# 704        1    ADULTO2        4         1      1      9         9         9
# 705        1    ADULTO3        4         2      9      9         9         1
# 706        0     IDOSO2        4         2      1      9         9         1
# 707        0     IDOSO3        1         9      1      1         2         1
# 708        1    ADULTO3        4         2      2      1         1         1
#
# ...

# %%
data_internacao = covidData['DT_INTERNA']

# %%
data_internacao_formatado = data_internacao

# %%
# data_saida.isnull().sum()
# data_internacao.isnull().sum()
# Out:
# 24

# %%
for i in data_internacao.count()N:
    data_internacao_formatado[i] = data_internacao[i].strftime('%d/%m/%Y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-c2a6d2ad0284> in <module>
# ----> 1 for i in data_internacao.count():
#       2     data_internacao_formatado[i] = data_internacao[i].strftime('%d/%m/%Y')
#
# TypeError: 'numpy.int32' object is not iterable

# %%
data_internacao
