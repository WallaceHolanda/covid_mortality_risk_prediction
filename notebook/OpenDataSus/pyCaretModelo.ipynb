# %%
# Para a correta execução do notebook será necessário instalar a biblioteca PyCaret
# pip install pycaret
# pip install openpyxl (Caso ocorra problema na leitura da base de dados)
# Tutorial: https://www.youtube.com/watch?v=88jD1nnkNfM&ab_channel=Let%27sData
# Site: https://www.learndatasci.com/tutorials/introduction-pycaret-machine-learning/
# !pip install pandas

#!pip install --upgrade pip
#!pip install openpyxl
#!pip install pycaret
#!pip install import-ipynb
#!pip install shap
#!pip install scikit-learn==0.23.2

# %%
from pycaret.classification import *

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#import import_ipynb
#import modelofuncoes as mf

# %%
import sklearn
# sklearn.__version__
# Anterior '0.24.1'

# %%
#covidData = pd.read_excel("../database/novosDados/balanceados/balanceados_70_30_Jan2021.xlsx")
#urlBase = 'ic-vacina-7030-sp-v2.xlsx'

# urlBase = 'PreProcessamento/balanceadas/IC/ba-ic-6040-sp.xlsx'
# urlBase = 'PreProcessamento/balanceadas/Smote/sm-ic-6040-sp.xlsx'

# Modelo OC
urlBase = 'PreProcessamento/balanceadas/Smote/sm-oc-7030-sp.xlsx'
alvo = 'evolucaoCaso'

covidData = pd.read_excel(urlBase)
covidData.shape

#covidData = mf.juntarLotes('7030', True)
#covidData[alvo].value_counts()
# Out:
# (6678, 38)

# %%
#colunasRemovidas = ['disturbiosOlfativos', 'disturbiosGustatorios', 'puerpera', 'fragilidadeImuno', 
#                    'gestante', 'obesidade', 'dataPrimeiraDose', 'dataSegundaDose']

## Teste 2
#colunasRemovidas = ['dataPrimeiraDose', 'dataSegundaDose']


## Teste 3 (Melhor)
# colunasRemovidas = ['disturbiosOlfativos', 'disturbiosGustatorios', 'puerpera', 'fragilidadeImuno', 
#                     'assintomatico', 'dataPrimeiraDose', 'dataSegundaDose', 'obesidade', 'renal', 'respiratoria']

## Teste 4
#colunasRemovidas = ['disturbiosOlfativos', 'disturbiosGustatorios', 'puerpera', 'fragilidadeImuno', 
#                    'assintomatico', 'dataPrimeiraDose', 'dataSegundaDose', 'renal', 'obesidade']

## Teste 5
#colunasRemovidas = ['disturbiosOlfativos', 'disturbiosGustatorios', 'puerpera', 'fragilidadeImuno', 
#                    'assintomatico', 'dataPrimeiraDose', 'dataSegundaDose', 'renal', 'obesidade', 'gestante', 
#                    'respiratoria']

# colunasRemovidas = ['assintomatico', 'asma', 'cefaleia', 'tosse', 'diarreia', 
#                     'dorNoPeito', 'hipotireoidismo', 'imunossupressao', 'puerpera', 
#                     'disturbiosGustatorios', 'disturbiosOlfativos', 'bronquite', 
#                     'dosNasCostas', 'gestante', 'respiratoria', 'sexo', 'febre', 
#                     'mialgia', 'cardiaca', 'hipertensao', 'diasSintomas', 
#                     'faltaDeAr', 'racaCor', 'congestaoNasal', 'renal', 'dorNoCorpo', 
#                     'vomito', 'fragilidadeImuno', 'cansaco']

# covidData = covidData.drop(columns = colunasRemovidas)
# covidData.shape

# %%
# (Modelo OC)
atributosSelecionados = ['faixaetaria', 'dispneia', 'qntVacinas', 'coriza', 'dorDeGarganta', 
                       'dorDeCabeca', 'obesidade', 'diabetes', 'faixaDiasSintomas', 'evolucaoCaso']

# (Modelo IC)
# atributosSelecionados = ['faixaetaria', 'dorDeCabeca', 'dorDeGarganta', 'renal', 'dispneia', 'diabetes',  
#                        'tosse', 'qntVacinas', 'faixaDiasSintomas', 'coriza', 'febre', 'evolucaoCaso']

# Removendo os atributos
covidData = covidData.loc[:, atributosSelecionados]

# %%
covidData.columns
# Out:
# Index(['faixaetaria', 'dispneia', 'qntVacinas', 'coriza', 'dorDeGarganta',
#        'dorDeCabeca', 'obesidade', 'diabetes', 'faixaDiasSintomas',
#        'evolucaoCaso'],
#       dtype='object')

# %%
covidData.dtypes
# Out:
# faixaetaria          int64
# dispneia             int64
# qntVacinas           int64
# coriza               int64
# dorDeGarganta        int64
# dorDeCabeca          int64
# obesidade            int64
# diabetes             int64
# faixaDiasSintomas    int64
# evolucaoCaso         int64
# dtype: object

# %%
setup_classificao = setup(data = covidData, target = alvo, train_size=0.7)
profile=True
# Out:
# <style type="text/css">
# #T_08c67_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_08c67_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08c67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_08c67_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_08c67_row0_col1" class="data row0 col1" >7275</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_08c67_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_08c67_row1_col1" class="data row1 col1" >evolucaoCaso</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_08c67_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_08c67_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_08c67_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_08c67_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_08c67_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_08c67_row4_col1" class="data row4 col1" >(6678, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_08c67_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_08c67_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_08c67_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_08c67_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_08c67_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_08c67_row7_col1" class="data row7 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_08c67_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_08c67_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_08c67_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_08c67_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_08c67_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_08c67_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_08c67_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_08c67_row11_col1" class="data row11 col1" >(4674, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_08c67_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_08c67_row12_col1" class="data row12 col1" >(2004, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_08c67_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_08c67_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_08c67_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_08c67_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_08c67_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_08c67_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_08c67_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_08c67_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_08c67_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_08c67_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_08c67_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_08c67_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_08c67_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_08c67_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_08c67_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_08c67_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_08c67_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_08c67_row21_col1" class="data row21 col1" >5f76</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_08c67_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_08c67_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_08c67_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_08c67_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_08c67_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_08c67_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_08c67_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_08c67_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_08c67_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_08c67_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_08c67_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_08c67_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_08c67_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_08c67_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_08c67_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_08c67_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_08c67_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_08c67_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_08c67_row30_col1" class="data row30 col1" >None</td>
#     </tr>

# %%
# get_config('X')

# %%
melhores_modelos = compare_models(n_select= 20)
# Out:
# <style type="text/css">
# #T_d58cc_ th {
#   text-align: left;
# }
# #T_d58cc_row0_col0, #T_d58cc_row0_col3, #T_d58cc_row0_col4, #T_d58cc_row1_col0, #T_d58cc_row1_col1, #T_d58cc_row1_col2, #T_d58cc_row1_col3, #T_d58cc_row1_col4, #T_d58cc_row1_col5, #T_d58cc_row1_col6, #T_d58cc_row1_col7, #T_d58cc_row2_col0, #T_d58cc_row2_col1, #T_d58cc_row2_col2, #T_d58cc_row2_col3, #T_d58cc_row2_col4, #T_d58cc_row2_col5, #T_d58cc_row2_col6, #T_d58cc_row2_col7, #T_d58cc_row3_col0, #T_d58cc_row3_col1, #T_d58cc_row3_col2, #T_d58cc_row3_col3, #T_d58cc_row3_col4, #T_d58cc_row3_col5, #T_d58cc_row3_col6, #T_d58cc_row3_col7, #T_d58cc_row4_col0, #T_d58cc_row4_col1, #T_d58cc_row4_col2, #T_d58cc_row4_col3, #T_d58cc_row4_col4, #T_d58cc_row4_col5, #T_d58cc_row4_col6, #T_d58cc_row4_col7, #T_d58cc_row5_col0, #T_d58cc_row5_col1, #T_d58cc_row5_col2, #T_d58cc_row5_col3, #T_d58cc_row5_col4, #T_d58cc_row5_col5, #T_d58cc_row5_col6, #T_d58cc_row5_col7, #T_d58cc_row6_col0, #T_d58cc_row6_col1, #T_d58cc_row6_col2, #T_d58cc_row6_col3, #T_d58cc_row6_col4, #T_d58cc_row6_col5, #T_d58cc_row6_col6, #T_d58cc_row6_col7, #T_d58cc_row7_col0, #T_d58cc_row7_col1, #T_d58cc_row7_col2, #T_d58cc_row7_col3, #T_d58cc_row7_col4, #T_d58cc_row7_col5, #T_d58cc_row7_col6, #T_d58cc_row7_col7, #T_d58cc_row8_col0, #T_d58cc_row8_col1, #T_d58cc_row8_col2, #T_d58cc_row8_col3, #T_d58cc_row8_col5, #T_d58cc_row8_col6, #T_d58cc_row8_col7, #T_d58cc_row9_col0, #T_d58cc_row9_col1, #T_d58cc_row9_col2, #T_d58cc_row9_col3, #T_d58cc_row9_col4, #T_d58cc_row9_col5, #T_d58cc_row9_col6, #T_d58cc_row9_col7, #T_d58cc_row10_col0, #T_d58cc_row10_col1, #T_d58cc_row10_col2, #T_d58cc_row10_col3, #T_d58cc_row10_col4, #T_d58cc_row10_col5, #T_d58cc_row10_col6, #T_d58cc_row10_col7, #T_d58cc_row11_col0, #T_d58cc_row11_col1, #T_d58cc_row11_col2, #T_d58cc_row11_col3, #T_d58cc_row11_col4, #T_d58cc_row11_col5, #T_d58cc_row11_col6, #T_d58cc_row11_col7, #T_d58cc_row12_col0, #T_d58cc_row12_col1, #T_d58cc_row12_col2, #T_d58cc_row12_col3, #T_d58cc_row12_col4, #T_d58cc_row12_col5, #T_d58cc_row12_col6, #T_d58cc_row12_col7, #T_d58cc_row13_col0, #T_d58cc_row13_col1, #T_d58cc_row13_col2, #T_d58cc_row13_col4, #T_d58cc_row13_col5, #T_d58cc_row13_col6, #T_d58cc_row13_col7 {
#   text-align: left;
# }
# #T_d58cc_row0_col1, #T_d58cc_row0_col2, #T_d58cc_row0_col5, #T_d58cc_row0_col6, #T_d58cc_row0_col7, #T_d58cc_row8_col4, #T_d58cc_row13_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d58cc_row0_col8, #T_d58cc_row1_col8, #T_d58cc_row2_col8, #T_d58cc_row3_col8, #T_d58cc_row4_col8, #T_d58cc_row5_col8, #T_d58cc_row6_col8, #T_d58cc_row7_col8, #T_d58cc_row8_col8, #T_d58cc_row9_col8, #T_d58cc_row10_col8, #T_d58cc_row11_col8, #T_d58cc_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d58cc_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d58cc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d58cc_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_d58cc_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_d58cc_row0_col1" class="data row0 col1" >0.7952</td>
#       <td id="T_d58cc_row0_col2" class="data row0 col2" >0.8645</td>
#       <td id="T_d58cc_row0_col3" class="data row0 col3" >0.8350</td>
#       <td id="T_d58cc_row0_col4" class="data row0 col4" >0.7746</td>
#       <td id="T_d58cc_row0_col5" class="data row0 col5" >0.8034</td>
#       <td id="T_d58cc_row0_col6" class="data row0 col6" >0.5905</td>
#       <td id="T_d58cc_row0_col7" class="data row0 col7" >0.5928</td>
#       <td id="T_d58cc_row0_col8" class="data row0 col8" >0.0510</td>
#     </tr>
#     <tr>
#       <th id="T_d58cc_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_d58cc_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_d58cc_row1_col1" class="data row1 col1" >0.7884</td>
#       <td id="T_d58cc_row1_col2" class="data row1 col2" >0.8547</td>
#       <td id="T_d58cc_row1_col3" class="data row1 col3" >0.8047</td>
#       <td id="T_d58cc_row1_col4" class="data row1 col4" >0.7806</td>
#       <td id="T_d58cc_row1_col5" class="data row1 col5" >0.7921</td>
#       <td id="T_d58cc_row1_col6" class="data row1 col6" >0.5768</td>
#       <td id="T_d58cc_row1_col7" class="data row1 col7" >0.5776</td>
#       <td id="T_d58cc_row1_col8" class="data row1 col8" >0.2680</td>
#     </tr>
#     <tr>
#       <th id="T_d58cc_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_d58cc_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_d58cc_row2_col1" class="data row2 col1" >0.7878</td>
#       <td id="T_d58cc_row2_col2" class="data row2 col2" >0.8596</td>
#       <td id="T_d58cc_row2_col3" class="data row2 col3" >0.8282</td>
#       <td id="T_d58cc_row2_col4" class="data row2 col4" >0.7671</td>
#       <td id="T_d58cc_row2_col5" class="data row2 col5" >0.7962</td>
#       <td id="T_d58cc_row2_col6" class="data row2 col6" >0.5755</td>
#       <td id="T_d58cc_row2_col7" class="data row2 col7" >0.5778</td>
#       <td id="T_d58cc_row2_col8" class="data row2 col8" >0.1590</td>
#     </tr>
#     <tr>
#       <th id="T_d58cc_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_d58cc_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_d58cc_row3_col1" class="data row3 col1" >0.7843</td>
#       <td id="T_d58cc_row3_col2" class="data row3 col2" >0.8552</td>
#       <td id="T_d58cc_row3_col3" class="data row3 col3" >0.8124</td>
#       <td id="T_d58cc_row3_col4" class="data row3 col4" >0.7702</td>
#       <td id="T_d58cc_row3_col5" class="data row3 col5" >0.7904</td>
#       <td id="T_d58cc_row3_col6" class="data row3 col6" >0.5686</td>
#       <td id="T_d58cc_row3_col7" class="data row3 col7" >0.5700</td>
#       <td id="T_d58cc_row3_col8" class="data row3 col8" >0.3900</td>
#     </tr>
#     <tr>
#       <th id="T_d58cc_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_d58cc_row4_col0" class="data row4 col0" >K Neighbors Classifier</td>
#       <td id="T_d58cc_row4_col1" class="data row4 col1" >0.7833</td>
#       <td id="T_d58cc_row4_col2" class="data row4 col2" >0.8412</td>
#       <td id="T_d58cc_row4_col3" class="data row4 col3" >0.7816</td>
#       <td id="T_d58cc_row4_col4" class="data row4 col4" >0.7853</td>
#       <td id="T_d58cc_row4_col5" class="data row4 col5" >0.7832</td>
#       <td id="T_d58cc_row4_col6" class="data row4 col6" >0.5665</td>
#       <td id="T_d58cc_row4_col7" class="data row4 col7" >0.5670</td>
#       <td id="T_d58cc_row4_col8" class="data row4 col8" >0.1140</td>
#     </tr>
#     <tr>
#       <th id="T_d58cc_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_d58cc_row5_col0" class="data row5 col0" >Ridge Classifier</td>
#       <td id="T_d58cc_row5_col1" class="data row5 col1" >0.7822</td>
#       <td id="T_d58cc_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_d58cc_row5_col3" class="data row5 col3" >0.8269</td>
#       <td id="T_d58cc_row5_col4" class="data row5 col4" >0.7601</td>
#       <td id="T_d58cc_row5_col5" class="data row5 col5" >0.7918</td>
#       <td id="T_d58cc_row5_col6" class="data row5 col6" >0.5643</td>
#       <td id="T_d58cc_row5_col7" class="data row5 col7" >0.5670</td>
#       <td id="T_d58cc_row5_col8" class="data row5 col8" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_d58cc_level0_row6" class="row_heading level0 row6" >lda</th>
#       <td id="T_d58cc_row6_col0" class="data row6 col0" >Linear D

# %%
melhores_modelos[1]
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=7275, verbose=0,
#                        warm_start=False)

# %%
# modelo_tunado = tune_model(melhores_modelos[1], n_iter = 20)
modelo_tunado = tune_model(melhores_modelos[1])
# Out:
# <style type="text/css">
# #T_eb0b0_row10_col0, #T_eb0b0_row10_col1, #T_eb0b0_row10_col2, #T_eb0b0_row10_col3, #T_eb0b0_row10_col4, #T_eb0b0_row10_col5, #T_eb0b0_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_eb0b0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb0b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb0b0_row0_col0" class="data row0 col0" >0.8013</td>
#       <td id="T_eb0b0_row0_col1" class="data row0 col1" >0.8886</td>
#       <td id="T_eb0b0_row0_col2" class="data row0 col2" >0.8205</td>
#       <td id="T_eb0b0_row0_col3" class="data row0 col3" >0.7901</td>
#       <td id="T_eb0b0_row0_col4" class="data row0 col4" >0.8050</td>
#       <td id="T_eb0b0_row0_col5" class="data row0 col5" >0.6026</td>
#       <td id="T_eb0b0_row0_col6" class="data row0 col6" >0.6030</td>
#     </tr>
#     <tr>
#       <th id="T_eb0b0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eb0b0_row1_col0" class="data row1 col0" >0.7906</td>
#       <td id="T_eb0b0_row1_col1" class="data row1 col1" >0.8561</td>
#       <td id="T_eb0b0_row1_col2" class="data row1 col2" >0.8675</td>
#       <td id="T_eb0b0_row1_col3" class="data row1 col3" >0.7519</td>
#       <td id="T_eb0b0_row1_col4" class="data row1 col4" >0.8056</td>
#       <td id="T_eb0b0_row1_col5" class="data row1 col5" >0.5812</td>
#       <td id="T_eb0b0_row1_col6" class="data row1 col6" >0.5882</td>
#     </tr>
#     <tr>
#       <th id="T_eb0b0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eb0b0_row2_col0" class="data row2 col0" >0.7821</td>
#       <td id="T_eb0b0_row2_col1" class="data row2 col1" >0.8473</td>
#       <td id="T_eb0b0_row2_col2" class="data row2 col2" >0.8291</td>
#       <td id="T_eb0b0_row2_col3" class="data row2 col3" >0.7578</td>
#       <td id="T_eb0b0_row2_col4" class="data row2 col4" >0.7918</td>
#       <td id="T_eb0b0_row2_col5" class="data row2 col5" >0.5641</td>
#       <td id="T_eb0b0_row2_col6" class="data row2 col6" >0.5666</td>
#     </tr>
#     <tr>
#       <th id="T_eb0b0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eb0b0_row3_col0" class="data row3 col0" >0.8056</td>
#       <td id="T_eb0b0_row3_col1" class="data row3 col1" >0.8827</td>
#       <td id="T_eb0b0_row3_col2" class="data row3 col2" >0.8675</td>
#       <td id="T_eb0b0_row3_col3" class="data row3 col3" >0.7719</td>
#       <td id="T_eb0b0_row3_col4" class="data row3 col4" >0.8169</td>
#       <td id="T_eb0b0_row3_col5" class="data row3 col5" >0.6111</td>
#       <td id="T_eb0b0_row3_col6" class="data row3 col6" >0.6159</td>
#     </tr>
#     <tr>
#       <th id="T_eb0b0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eb0b0_row4_col0" class="data row4 col0" >0.7623</td>
#       <td id="T_eb0b0_row4_col1" class="data row4 col1" >0.8110</td>
#       <td id="T_eb0b0_row4_col2" class="data row4 col2" >0.8333</td>
#       <td id="T_eb0b0_row4_col3" class="data row4 col3" >0.7303</td>
#       <td id="T_eb0b0_row4_col4" class="data row4 col4" >0.7784</td>
#       <td id="T_eb0b0_row4_col5" class="data row4 col5" >0.5245</td>
#       <td id="T_eb0b0_row4_col6" class="data row4 col6" >0.5298</td>
#     </tr>
#     <tr>
#       <th id="T_eb0b0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_eb0b0_row5_col0" class="data row5 col0" >0.8094</td>
#       <td id="T_eb0b0_row5_col1" class="data row5 col1" >0.8887</td>
#       <td id="T_eb0b0_row5_col2" class="data row5 col2" >0.8419</td>
#       <td id="T_eb0b0_row5_col3" class="data row5 col3" >0.7912</td>
#       <td id="T_eb0b0_row5_col4" class="data row5 col4" >0.8157</td>
#       <td id="T_eb0b0_row5_col5" class="data row5 col5" >0.6188</td>
#       <td id="T_eb0b0_row5_col6" class="data row5 col6" >0.6201</td>
#     </tr>
#     <tr>
#       <th id="T_eb0b0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_eb0b0_row6_col0" class="data row6 col0" >0.7987</td>
#       <td id="T_eb0b0_row6_col1" class="data row6 col1" >0.8710</td>
#       <td id="T_eb0b0_row6_col2" class="data row6 col2" >0.8590</td>
#       <td id="T_eb0b0_row6_col3" class="data row6 col3" >0.7672</td>
#       <td id="T_eb0b0_row6_col4" class="data row6 col4" >0.8105</td>
#       <td id="T_eb0b0_row6_col5" class="data row6 col5" >0.5973</td>
#       <td id="T_eb0b0_row6_col6" class="data row6 col6" >0.6017</td>
#     </tr>
#     <tr>
#       <th id="T_eb0b0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_eb0b0_row7_col0" class="data row7 col0" >0.7987</td>
#       <td id="T_eb0b0_row7_col1" class="data row7 col1" >0.8734</td>
#       <td id="T_eb0b0_row7_col2" class="data row7 col2" >0.8547</td>
#       <td id="T_eb0b0_row7_col3" class="data row7 col3" >0.7692</td>
#       <td id="T_eb0b0_row7_col4" class="data row7 col4" >0.8097</td>
#       <td id="T_eb0b0_row7_col5" class="data row7 col5" >0.5973</td>
#       <td id="T_eb0b0_row7_col6" class="data row7 col6" >0.6011</td>
#     </tr>
#     <tr>
#       <th id="T_eb0b0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_eb0b0_row8_col0" class="data row8 col0" >0.7794</td>
#       <td id="T_eb0b0_row8_col1" class="data row8 col1" >0.8411</td>
#       <td id="T_eb0b0_row8_col2" class="data row8 col2" >0.8504</td>
#       <td id="T_eb0b0_row8_col3" class="data row8 col3" >0.7453</td>
#       <td id="T_eb0b0_row8_col4" class="data row8 col4" >0.7944</td>
#       <td id="T_eb0b0_row8_col5" class="data row8 col5" >0.5588</td>
#       <td id="T_eb0b0_row8_col6" class="data row8 col6" >0.5644</td>
#     </tr>
#     <tr>
#       <th id="T_eb0b0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_eb0b0_row9_col0" class="data row9 col0" >0.7923</td>
#       <td id="T_eb0b0_row9_col1" class="data row9 col1" >0.8629</td>
#       <td id="T_eb0b0_row9_col2" class="data row9 col2" >0.8291</td>
#       <td id="T_eb0b0_row9_col3" class="data row9 col3" >0.7729</td>
#       <td id="T_eb0b0_row9_col4" class="data row9 col4" >0.8000</td>
#       <td id="T_eb0b0_row9_col5" class="data row9 col5" >0.5845</td>
#       <td id="T_eb0b0_row9_col6" class="data row9 col6" >0.5861</td>
#     </tr>
#     <tr>
#       <th id="T_eb0b0_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_eb0b0_row10_col0" class="data row10 col0" >0.7920</td>
#       <td id="T_eb0b0_row10_col1" class="data row10 col1" >0.8623</td>
#       <td id="T_eb0b0_row10_col2" class="data row10 col2" >0.8453</td>
#       <td id="T_eb0b0_row10_col3" class="data row10 col3" >0.7648</td>
#       <td id="T_eb0b0_row10_col4" class="data row10 col4" >0.8028</td>
#       <td id="T_eb0b0_row10_col5" class="data row10 col5" >0.5840</td>
#       <td id="T_eb0b0_row10_col6" class="data row10 col6" >0.5877</td>
#     </tr>
#     <tr>
#       <th id="T_eb0b0_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_eb0b0_row11_col0" class="data row11 col0" >0.0134</td>
#       <td id="T_eb0b0_row11_col1" class="data row11 col1" >0.0231</td>
#       <td id="T_eb0b0_row11_col2" class="data row11 col2" >0.0161</td>
#       <td id="T_eb0b0_row11_col3" class="data row11 col3" >0.0181</td>
#       <td id="T_eb0b0_row11_col4" class="data row11 col4" >0.0113</td>
#       <td id="T_eb0b0_row11_col5" class="data row11 col5" >0.0269</td>
#       <td id="T_eb0b0_row11_col6" class="data row11 col6" >0.0261</td>
#     </tr>
#   </tbody>
# </table>

# %%
modelo_tunado
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight={},
#                        criterion='gini', max_depth=11, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0002, min_impurity_split=None,
#                        min_samples_leaf=2, min_samples_split=9,
#                        min_weight_fraction_leaf=0.0, n_estimators=250,
#                        n_jobs=-1, oob_score=False, random_state=7275, verbose=0,
#                        warm_start=False)

# %%
modelo_tunado
#modelo_final = finalize_model(random_forest_tunado)

# %% [markdown]
# # Usando o Feature Selection

# %%
#setupFeature = setup(data = covidData, target = 'EVOLUCAO', feature_selection = True)

# %%
#setupFeature
#plot_model(melhores_modelos[0], plot='feature')

# %%
#lr = create_model('lr')
#plotting a model
#plot_model(melhores_modelos[0])

# %% [markdown]
# ## Treinando o melhor modelo

# %%
modeloDados = covidData
modeloDados.shape
#modeloDados = pd.read_excel(urlBase)

# %% [markdown]
# ### Separando os dados (Treinamento e Teste)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(modeloDados.drop(alvo,axis=1),
                                                    modeloDados[alvo],
                                                    test_size=0.3,
                                                    random_state=42);

# %% [markdown]
# ### Escolhendo o Algoritmo

# %%
from sklearn.ensemble import GradientBoostingClassifier
modeloClassificador = GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
                           learning_rate=0.1, loss='deviance', max_depth=3,
                           max_features=None, max_leaf_nodes=None,
                           min_impurity_decrease=0.0, min_impurity_split=None,
                           min_samples_leaf=1, min_samples_split=2,
                           min_weight_fraction_leaf=0.0, n_estimators=100,
                           n_iter_no_change=None, presort='deprecated',
                           random_state=2333, subsample=1.0, tol=0.0001,
                           validation_fraction=0.1, verbose=0,
                           warm_start=False)

# %%
modeloClassificador

# %%
# from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier

modeloClassificador = AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
                   n_estimators=50, random_state=410)

# %%
from sklearn.linear_model import LogisticRegression

modeloClassificador = LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
                   intercept_scaling=1, l1_ratio=None, max_iter=1000,
                   multi_class='auto', n_jobs=None, penalty='l2',
                   random_state=2576, solver='lbfgs', tol=0.0001, verbose=0,
                   warm_start=False)

# %%
from sklearn.ensemble import RandomForestClassifier
modeloClassificador = RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=None, max_features='auto',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=1, min_samples_split=2,
                       min_weight_fraction_leaf=0.0, n_estimators=100,
                       n_jobs=-1, oob_score=False, random_state=7374, verbose=0,
                       warm_start=False)

# modeloClassificador.fit(x_train, y_train)

# %% [markdown]
# ### Desempenho - Acurácia Geral

# %%
from sklearn.metrics import accuracy_score

# Fit nos dados
modeloClassificador.fit(x_train, y_train)

#Realizando a predição
resultado = modeloClassificador.predict(x_test)

# Verificando a acurácia
print(accuracy_score(y_test, resultado))

# %% [markdown]
# ### Desempenho - Cross Validation

# %%
from sklearn.model_selection import cross_val_score

kfolds = 3
data, target = modeloDados.drop(columns = [alvo]), modeloDados[alvo]
scores = cross_val_score(modeloClassificador, data, target, cv = kfolds, scoring = "accuracy")

# %%
print("Resultado dos k testes", scores)
print("Média dos testes", scores.mean())
print("Desvio Padrão dos testes", scores.std())

# %% [markdown]
# ### Desempenho - Por Classes

# %%
from sklearn import metrics
#print(metrics.classification_report(y_test,resultado))

report = metrics.classification_report(y_test,resultado, output_dict=True)
df = pd.DataFrame(report).transpose()

precisao = round(df.loc['0']['precision'],3) * 100

valor = str(precisao) + "%"

valor

df

round(df.loc['0']['recall'],3) * 100
round(df.loc['0']['f1-score'],3) * 100

# %% [markdown]
# ### Importância das Features

# %%
# Verificando os melhores dados
# from sklearn.ensemble import RandomForestClassifier

feature_importances = pd.DataFrame(modeloClassificador.feature_importances_,
                                   index = x_train.columns,
                                    columns=['importance']).sort_values('importance', ascending=False)
feature_importances

# %%
importance = modeloClassificador.coef_[0]
#importance is a list so you can plot it. 
feat_importances = pd.Series(importance)
feat_importances.nlargest(20).plot(kind='barh',title = 'Feature Importance')

# %%
from sklearn import metrics
import matplotlib.pyplot as plt

# Fit nos dados
modeloClassificador.fit(x_train, y_train)

#Realizando a predição
resultado = modeloClassificador.predict(x_test)

y_pred_proba = modeloClassificador.predict_proba(x_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()
